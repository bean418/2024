# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes #당뇨병

# %%
diabete=load_diabetes()
df=pd.DataFrame(diabete.data, columns=diabete.feature_names)
df['degree']=diabete.target
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  degree
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
input=diabete.data
output=df['degree']

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_output, test_output=train_test_split(input,output)

# %%
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor(max_depth=4)

# %%
RFR.fit(train_input,train_output)
# Out:
# RandomForestRegressor(max_depth=4)

# %%
RFR.feature_importances_
# Out:
# array([0.01468047, 0.0055692 , 0.2843183 , 0.09223496, 0.01947702,
#        0.02443845, 0.02372858, 0.02005968, 0.47664899, 0.03884435])

# %%
diabete.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
np.argmax(RFR.feature_importances_)
# Out:
# 8

# %%
np.corrcoef(RFR.predict(test_input),test_output)
# Out:
# array([[1.        , 0.65079171],
#        [0.65079171, 1.        ]])

# %%
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(RFR.predict(test_input),test_output)
MSE
# Out:
# 3523.2281436801104

# %%
NMSE=MSE/np.max(test_output)
NMSE
# Out:
# 10.332047342170412

# %%
# x는 데이터의 인덱스
# y는 예측값(predict), 실제 값(test_output)

plt.figure(figsize=(14,7), dpi=200)
plt.plot(range(len(test_input)),RFR.predict(test_input),'g',
        label='predict')
plt.plot(range(len(test_input)),test_output,'b', alpha=0.3,
        label='real')
plt.legend()
plt.xlabel("idx")
plt.ylabel("degree")
plt.show()
